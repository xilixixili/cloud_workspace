# %% [markdown]
# ### Tf-keras 和 keras 区别
# - tf.kears

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import sklearn 
import pandas as pd
import os
import sys
import time
import tensorflow as tf

from tensorflow import keras

print(tf.__version__)
print(sys.version_info)
for module in mpl,np,sklearn,tf,keras:
    print(module.__name__,module.__version__)
# Out:
# 2.1.0
# sys.version_info(major=3, minor=6, micro=9, releaselevel='final', serial=0)
# matplotlib 3.2.1
# numpy 1.18.2
# sklearn 0.22.2.post1
# tensorflow 2.1.0
# tensorflow_core.python.keras.api._v2.keras 2.2.4-tf

# %%
from sklearn.datasets import fetch_california_housing
housing=fetch_california_housing()
print(housing.DESCR)
print(housing.data.shape)
print(housing.target.shape)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 20640
#
#     :Number of Attributes: 8 numeric, predictive attributes and the target
#
#     :Attribute Information:
#         - MedInc        median income in block
#         - HouseAge      median house age in block
#         - AveRooms      average number of rooms
#         - AveBedrms     average number of bedrooms
#         - Population    block population
#         - AveOccup      average house occupancy
#         - Latitude      house block latitude
#         - Longitude     house block longitude
#
#     :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# http://lib.stat.cmu.edu/datasets/
#
# The target variable is the median house value for California districts.
#
# This dataset was derived from the 1990 U.S. census, using one row per census
# block group. A block group is the smallest geographical unit for which the U.S.
# Census Bureau publishes sample data (a block group typically has a population
# of 600 to 3,000 people).
#
# It can be downloaded/loaded using the
# :func:`sklearn.datasets.fetch_california_housing` function.
#
# .. topic:: References
#
#     - Pace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,
#       Statistics and Probability Letters, 33 (1997) 291-297
#
# (20640, 8)
# (20640,)

# %%
from sklearn.model_selection import train_test_split
x_train_all,x_test,y_train_all,y_test=train_test_split(housing.data,housing.target,random_state=7)
x_train,x_valid,y_train,y_valid=train_test_split(x_train_all,y_train_all,random_state=11)

print(x_valid.shape,y_valid.shape)
print(x_train.shape,y_train.shape)
print(x_test.shape,y_test.shape)
# Out:
# (3870, 8) (3870,)
# (11610, 8) (11610,)
# (5160, 8) (5160,)

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
x_train_s=scaler.fit_transform(x_train)
x_valid_s=scaler.fit_transform(x_valid)
x_test_s=scaler.transform(x_test)

# %%
# learning rate:[1e-4,3e-4,1e-3,3e-3,1e-2,3e-2]
learning_rates=[1e-4,3e-4,1e-3,3e-3,1e-2,3e-2]
histories=[]
for lr in learning_rates:
    model=keras.models.Sequential([
        keras.layers.Dense(30,activation='relu',input_shape=x_train.shape[1:]),
        keras.layers.Dense(1),
    ])
    optimizer=keras.optimizers.SGD(lr)
    model.compile(loss='mean_squared_error',optimizer=optimizer)

    callbacks=[keras.callbacks.EarlyStopping(patience=5,min_delta=1e-2)]
    history=model.fit(x_train_s,y_train,validation_data=(x_valid_s,y_valid),epochs=100,callbacks=callbacks)
    histories.append(history)
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/100
# 11610/11610 [==============================] - 1s 62us/sample - loss: 4.3339 - val_loss: 3.7637
# Epoch 2/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 3.0017 - val_loss: 2.7759
# Epoch 3/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 2.2611 - val_loss: 2.1953
# Epoch 4/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 1.8198 - val_loss: 1.8350
# Epoch 5/100
# 11610/11610 [==============================] - 0s 42us/sample - loss: 1.5395 - val_loss: 1.5937
# Epoch 6/100
# 11610/11610 [==============================] - 1s 46us/sample - loss: 1.3482 - val_loss: 1.4215
# Epoch 7/100
# 11610/11610 [==============================] - 0s 42us/sample - loss: 1.2111 - val_loss: 1.2939
# Epoch 8/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 1.1092 - val_loss: 1.1968
# Epoch 9/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 1.0323 - val_loss: 1.1221
# Epoch 10/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.9731 - val_loss: 1.0637
# Epoch 11/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.9271 - val_loss: 1.0172
# Epoch 12/100
# 11610/11610 [==============================] - 1s 44us/sample - loss: 0.8910 - val_loss: 0.9804
# Epoch 13/100
# 11610/11610 [==============================] - 0s 42us/sample - loss: 0.8627 - val_loss: 0.9511
# Epoch 14/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.8400 - val_loss: 0.9270
# Epoch 15/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.8218 - val_loss: 0.9072
# Epoch 16/100
# 11610/11610 [==============================] - 1s 43us/sample - loss: 0.8068 - val_loss: 0.8904
# Epoch 17/100
# 11610/11610 [==============================] - 0s 42us/sample - loss: 0.7942 - val_loss: 0.8761
# Epoch 18/100
# 11610/11610 [==============================] - 0s 43us/sample - loss: 0.7835 - val_loss: 0.8638
# Epoch 19/100
# 11610/11610 [==============================] - 0s 42us/sample - loss: 0.7742 - val_loss: 0.8531
# Epoch 20/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.7660 - val_loss: 0.8435
# Epoch 21/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.7586 - val_loss: 0.8349
# Epoch 22/100
# 11610/11610 [==============================] - 0s 42us/sample - loss: 0.7518 - val_loss: 0.8271
# Epoch 23/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.7456 - val_loss: 0.8198
# Epoch 24/100
# 11610/11610 [==============================] - 0s 42us/sample - loss: 0.7397 - val_loss: 0.8130
# Epoch 25/100
# 11610/11610 [==============================] - 0s 43us/sample - loss: 0.7342 - val_loss: 0.8065
# Epoch 26/100
# 11610/11610 [==============================] - 0s 43us/sample - loss: 0.7289 - val_loss: 0.8004
# Epoch 27/100
# 11610/11610 [==============================] - 0s 43us/sample - loss: 0.7240 - val_loss: 0.7946
# Epoch 28/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.7192 - val_loss: 0.7892
# Epoch 29/100
# 11610/11610 [==============================] - 0s 42us/sample - loss: 0.7146 - val_loss: 0.7838
# Epoch 30/100
# 11610/11610 [==============================] - 0s 42us/sample - loss: 0.7101 - val_loss: 0.7789
# Epoch 31/100
# 11610/11610 [==============================] - 1s 43us/sample - loss: 0.7059 - val_loss: 0.7739
# Epoch 32/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.7017 - val_loss: 0.7692
# Epoch 33/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.6976 - val_loss: 0.7645
# Epoch 34/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.6937 - val_loss: 0.7601
# Epoch 35/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.6898 - val_loss: 0.7557
# Epoch 36/100
# 11610/11610 [==============================] - 1s 43us/sample - loss: 0.6860 - val_loss: 0.7514
# Epoch 37/100
# 11610/11610 [==============================] - 1s 46us/sample - loss: 0.6824 - val_loss: 0.7473
# Epoch 38/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.6788 - val_loss: 0.7433
# Epoch 39/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.6753 - val_loss: 0.7393
# Epoch 40/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.6718 - val_loss: 0.7353
# Epoch 41/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.6684 - val_loss: 0.7315
# Epoch 42/100
# 11610/11610 [==============================] - 0s 42us/sample - loss: 0.6651 - val_loss: 0.7278
# Epoch 43/100
# 11610/11610 [==============================] - 1s 44us/sample - loss: 0.6618 - val_loss: 0.7240
# Epoch 44/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.6586 - val_loss: 0.7205
# Epoch 45/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.6554 - val_loss: 0.7170
# Epoch 46/100
# 11610/11610 [==============================] - 0s 42us/sample - loss: 0.6523 - val_loss: 0.7136
# Epoch 47/100
# 11610/11610 [==============================] - 1s 44us/sample - loss: 0.6493 - val_loss: 0.7101
# Epoch 48/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.6462 - val_loss: 0.7068
# Epoch 49/100
# 11610/11610 [==============================] - 1s 44us/sample - loss: 0.6433 - val_loss: 0.7036
# Epoch 50/100
# 11610/11610 [==============================] - 0s 42us/sample - loss: 0.6404 - val_loss: 0.7004
# Epoch 51/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.6375 - val_loss: 0.6972
# Epoch 52/100
# 11610/11610 [==============================] - 0s 42us/sample - loss: 0.6347 - val_loss: 0.6942
# Epoch 53/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.6320 - val_loss: 0.6912
# Epoch 54/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.6292 - val_loss: 0.6881
# Epoch 55/100
# 11610/11610 [==============================] - 1s 44us/sample - loss: 0.6265 - val_loss: 0.6849
# Epoch 56/100
# 11610/11610 [==============================] - 0s 42us/sample - loss: 0.6239 - val_loss: 0.6820
# Epoch 57/100
# 11610/11610 [==============================] - 1s 44us/sample - loss: 0.6213 - val_loss: 0.6791
# Epoch 58/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.6187 - val_loss: 0.6762
# Epoch 59/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.6162 - val_loss: 0.6734
# Epoch 60/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.6137 - val_loss: 0.6706
# Epoch 61/100
# 11610/11610 [==============================] - 1s 44us/sample - loss: 0.6112 - val_loss: 0.6679
# Epoch 62/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.6088 - val_loss: 0.6652
# Epoch 63/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.6065 - val_loss: 0.6625
# Epoch 64/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.6041 - val_loss: 0.6599
# Epoch 65/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.6018 - val_loss: 0.6572
# Epoch 66/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.5995 - val_loss: 0.6546
# Epoch 67/100
# 11610/11610 [==============================] - 1s 46us/sample - loss: 0.5972 - val_loss: 0.6521
# Epoch 68/100
# 11610/11610 [==============================] - 0s 42us/sample - loss: 0.5950 - val_loss: 0.6496
# Epoch 69/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.5928 - val_loss: 0.6472
# Epoch 70/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.5907 - val_loss: 0.6448
# Epoch 71/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.5885 - val_loss: 0.6424
# Epoch 72/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.5865 - val_loss: 0.6401
# Epoch 73/100
# 11610/11610 [==============================] - 1s 44us/sample - loss: 0.5844 - val_loss: 0.6377
# Epoch 74/100
# 11610/11610 [==============================] - 0s 42us/sample - loss: 0.5824 - val_loss: 0.6354
# Epoch 75/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.5804 - val_loss: 0.6331
# Epoch 76/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.5784 - val_loss: 0.6309
# Epoch 77/100
# 11610/11610 [==============================] - 1s 43us/sample - loss: 0.5765 - val_loss: 0.6287
# Epoch 78/100
# 11610/11610 [==============================] - 0s 42us/sample - loss: 0.5746 - val_loss: 0.6265
# Epoch 79/100
# 11610/11610 [==============================] - 0s 43us/sample - loss: 0.5727 - val_loss: 0.6244
# Epoch 80/100
# 11610/11610 [==============================] - 0s 43us/sample - loss: 0.5708 - val_loss: 0.6222
# Epoch 81/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.5690 - val_loss: 0.6201
# Epoch 82/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.5672 - val_loss: 0.6180
# Epoch 83/100
# 11610/11610 [==============================] - 0s 42us/sample - loss: 0.5654 - val_loss: 0.6161
# Epoch 84/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.5636 - val_loss: 0.6140
# Epoch 85/100
# 11610/11610 [==============================] - 0s 42us/sample - loss: 0.5619 - val_loss: 0.6120
# Epoch 86/100
# 11610/11610 [==============================] - 0s 43us/sample - loss: 0.5602 - val_loss: 0.6099
# Epoch 87/100
# 11610/11610 [==============================] - 0s 43us/sample - loss: 0.5585 - val_loss: 0.6079
# Epoch 88/100
# 11610/11610 [==============================] - 0s 43us/sample - loss: 0.5569 - val_loss: 0.6061
# Epoch 89/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.5552 - val_loss: 0.6041
# Epoch 90/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.5536 - val_loss: 0.6023
# Epoch 91/100
# 11610/11610 [==============================] - 0s 42us/sample - loss: 0.5520 - val_loss: 0.6005
# Epoch 92/100
# 11610/11610 [==============================] - 1s 43us/sample - loss: 0.5504 - val_loss: 0.5985
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/100
# 11610/11610 [==============================] - 1s 60us/sample - loss: 3.7213 - val_loss: 2.8076
# Epoch 2/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 2.1490 - val_loss: 1.8056
# Epoch 3/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 1.4701 - val_loss: 1.3391
# Epoch 4/100
# 11610/11610 [==============================] - 0s 42us/sample - loss: 1.1413 - val_loss: 1.0994
# Epoch 5/100
# 11610/11610 [==============================] - 1s 46us/sample - loss: 0.9653 - val_loss: 0.9679
# Epoch 6/100
# 11610/11610 [==============================] - 0s 42us/sample - loss: 0.8628 - val_loss: 0.8887
# Epoch 7/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.8013 - val_loss: 0.8397
# Epoch 8/100
# 11610/11610 [==============================] - 0s 42us/sample - loss: 0.7620 - val_loss: 0.8082
# Epoch 9/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.7352 - val_loss: 0.7853
# Epoch 10/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.7155 - val_loss: 0.7680
# Epoch 11/100
# 11610/11610 [==============================] - 1s 43us/sample - loss: 0.7001 - val_loss: 0.7545
# Epoch 12/100
# 11610/11610 [==============================] - 0s 42us/sample - loss: 0.6875 - val_loss: 0.7430
# Epoch 13/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.6767 - val_loss: 0.7333
# Epoch 14/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.6672 - val_loss: 0.7248
# Epoch 15/100
# 11610/11610 [==============================] - 1s 44us/sample - loss: 0.6588 - val_loss: 0.7166
# Epoch 16/100
# 11610/11610 [==============================] - 0s 43us/sample - loss: 0.6511 - val_loss: 0.7098
# Epoch 17/100
# 11610/11610 [==============================] - 0s 43us/sample - loss: 0.6440 - val_loss: 0.7028
# Epoch 18/100
# 11610/11610 [==============================] - 0s 42us/sample - loss: 0.6373 - val_loss: 0.6961
# Epoch 19/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.6310 - val_loss: 0.6899
# Epoch 20/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.6250 - val_loss: 0.6838
# Epoch 21/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.6193 - val_loss: 0.6779
# Epoch 22/100
# 11610/11610 [==============================] - 0s 42us/sample - loss: 0.6138 - val_loss: 0.6721
# Epoch 23/100
# 11610/11610 [==============================] - 1s 45us/sample - loss: 0.6086 - val_loss: 0.6668
# Epoch 24/100
# 11610/11610 [==============================] - 0s 43us/sample - loss: 0.6035 - val_loss: 0.6620
# Epoch 25/100
# 11610/11610 [==============================] - 1s 43us/sample - loss: 0.5986 - val_loss: 0.6568
# Epoch 26/100
# 11610/11610 [==============================] - 0s 43us/sample - loss: 0.5939 - val_loss: 0.6516
# Epoch 27/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.5894 - val_loss: 0.6467
# Epoch 28/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.5850 - val_loss: 0.6420
# Epoch 29/100
# 11610/11610 [==============================] - 0s 42us/sample - loss: 0.5806 - val_loss: 0.6377
# Epoch 30/100
# 11610/11610 [==============================] - 0s 43us/sample - loss: 0.5765 - val_loss: 0.6332
# Epoch 31/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.5725 - val_loss: 0.6285
# Epoch 32/100
# 11610/11610 [==============================] - 0s 42us/sample - loss: 0.5686 - val_loss: 0.6240
# Epoch 33/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.5649 - val_loss: 0.6201
# Epoch 34/100
# 11610/11610 [==============================] - 0s 42us/sample - loss: 0.5612 - val_loss: 0.6158
# Epoch 35/100
# 11610/11610 [==============================] - 1s 44us/sample - loss: 0.5577 - val_loss: 0.6125
# Epoch 36/100
# 11610/11610 [==============================] - 1s 45us/sample - loss: 0.5544 - val_loss: 0.6085
# Epoch 37/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.5512 - val_loss: 0.6054
# Epoch 38/100
# 11610/11610 [==============================] - 0s 42us/sample - loss: 0.5480 - val_loss: 0.6017
# Epoch 39/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.5450 - val_loss: 0.5982
# Epoch 40/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.5421 - val_loss: 0.5947
# Epoch 41/100
# 11610/11610 [==============================] - 0s 42us/sample - loss: 0.5392 - val_loss: 0.5914
# Epoch 42/100
# 11610/11610 [==============================] - 1s 43us/sample - loss: 0.5364 - val_loss: 0.5878
# Epoch 43/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.5338 - val_loss: 0.5847
# Epoch 44/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.5313 - val_loss: 0.5820
# Epoch 45/100
# 11610/11610 [==============================] - 0s 43us/sample - loss: 0.5289 - val_loss: 0.5787
# Epoch 46/100
# 11610/11610 [==============================] - 1s 43us/sample - loss: 0.5265 - val_loss: 0.5761
# Epoch 47/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.5242 - val_loss: 0.5728
# Epoch 48/100
# 11610/11610 [==============================] - 1s 44us/sample - loss: 0.5221 - val_loss: 0.5702
# Epoch 49/100
#  4704/11610 [===========>..................] - ETA: 0s - loss: 0.5481

# %%
def plot_learning_curves(history):
    pd.DataFrame(history.history).plot(figsize=(8,5))
    plt.grid(True)
    plt.gca().set_ylim(0,1)
    plt.show()
for history in histories:
    plot_learning_curves(history)

# %%
model.evaluate(x_test_s,y_test)
# Out:
# 5160/5160 [==============================] - 0s 21us/sample - loss: 0.4020
# 0.40204299263251847
