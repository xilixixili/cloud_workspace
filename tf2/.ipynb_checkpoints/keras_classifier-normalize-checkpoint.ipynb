# %% [markdown]
# ### Tf-keras 和 keras 区别
# - tf.kears

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import sklearn 
import pandas as pd
import os
import sys
import time
import tensorflow as tf

from tensorflow import keras

print(tf.__version__)
print(sys.version_info)
for module in mpl,np,sklearn,tf,keras:
    print(module.__name__,module.__version__)
# Out:
# 2.1.0
# sys.version_info(major=3, minor=6, micro=9, releaselevel='final', serial=0)
# matplotlib 3.2.1
# numpy 1.18.2
# sklearn 0.22.2.post1
# tensorflow 2.1.0
# tensorflow_core.keras 2.2.4-tf

# %%
fashion_mnist = keras.datasets.fashion_mnist
(x_train_all,y_train_all),(x_test,y_test)=fashion_mnist.load_data()
x_valid,x_train=x_train_all[:5000],x_train_all[5000:]
y_valid,y_train=y_train_all[:5000],y_train_all[5000:]

print(x_valid.shape,y_valid.shape)
print(x_train.shape,y_train.shape)
print(x_test.shape,y_test.shape)
# Out:
# (5000, 28, 28) (5000,)
# (55000, 28, 28) (55000,)
# (10000, 28, 28) (10000,)

# %%
type(xa_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e4a4067b2150> in <module>
# ----> 1 type(xa_train)
#
# NameError: name 'xa_train' is not defined

# %%
def show_single_image(img_arr):
    plt.imshow(img_arr,cmap='binary')
    plt.show()
show_single_image(x_train[0])

# %%
def show_image(n_rows,n_cols,x_data,y_data,class_names):
    assert len(x_data)==len(y_data)
    assert n_rows*n_cols<len(x_data)
    plt.figure(figsize=(n_cols*1.4,n_rows*1.6))
    for row in range(n_rows):
        for col in range(n_cols):
            index = n_cols * row+col
            plt.subplot(n_rows,n_cols,index+1)
            plt.imshow(x_data[index],cmap='binary',interpolation='nearest')
            plt.axis('off')
            plt.title(class_names[y_data[index]])
    plt.show()
    
class_names=['T-shirt','Trouse','Pullover','Dress','Coat','Sandal','Shirt','Sneaker','Bag','Ankle boot']

show_image(5,7,x_train,y_train,class_names)

# %%
# tf.keras.models.Sequential()
"""
model=keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28,28]))
model.add(keras.layers.Dense(300,activation='relu'))
model.add(keras.layers.Dense(100,activation='relu'))
model.add(keras.layers.Dense(10,activation='softmax'))
"""
model=keras.models.Sequential([
    keras.layers.Flatten(input_shape=[28,28]),
    keras.layers.Dense(300,activation='relu'),
    keras.layers.Dense(100,activation='relu'),
    keras.layers.Dense(10,activation='softmax')
])


model.compile(loss='sparse_categorical_crossentropy',optimizer='sgd',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 300)               235500
# _________________________________________________________________
# dense_4 (Dense)              (None, 100)               30100
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 266,610
# Trainable params: 266,610
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.layers
# Out:
# [<tensorflow.python.keras.layers.core.Flatten at 0x7fbccdf8dd30>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7fbccdf8dac8>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7fbccdf8d278>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7fbccdf8d4e0>]

# %%
history=model.fit(x_train,y_train,epochs=10,validation_data=(x_valid,y_valid))
# Out:
# Train on 55000 samples, validate on 5000 samples
# Epoch 1/10
# 55000/55000 [==============================] - 5s 95us/sample - loss: nan - accuracy: 0.1007 - val_loss: nan - val_accuracy: 0.0914
# Epoch 2/10
# 55000/55000 [==============================] - 5s 87us/sample - loss: nan - accuracy: 0.1008 - val_loss: nan - val_accuracy: 0.0914
# Epoch 3/10
# 55000/55000 [==============================] - 5s 88us/sample - loss: nan - accuracy: 0.1008 - val_loss: nan - val_accuracy: 0.0914
# Epoch 4/10
# 55000/55000 [==============================] - 5s 84us/sample - loss: nan - accuracy: 0.1008 - val_loss: nan - val_accuracy: 0.0914
# Epoch 5/10
# 55000/55000 [==============================] - 5s 83us/sample - loss: nan - accuracy: 0.1008 - val_loss: nan - val_accuracy: 0.0914
# Epoch 6/10
# 55000/55000 [==============================] - 5s 82us/sample - loss: nan - accuracy: 0.1008 - val_loss: nan - val_accuracy: 0.0914
# Epoch 7/10
# 55000/55000 [==============================] - 5s 89us/sample - loss: nan - accuracy: 0.1008 - val_loss: nan - val_accuracy: 0.0914
# Epoch 8/10
# 55000/55000 [==============================] - 5s 95us/sample - loss: nan - accuracy: 0.1008 - val_loss: nan - val_accuracy: 0.0914
# Epoch 9/10
# 55000/55000 [==============================] - 5s 99us/sample - loss: nan - accuracy: 0.1008 - val_loss: nan - val_accuracy: 0.0914
# Epoch 10/10
# 55000/55000 [==============================] - 5s 96us/sample - loss: nan - accuracy: 0.1008 - val_loss: nan - val_accuracy: 0.0914

# %%
type(history)
# Out:
# tensorflow.python.keras.callbacks.History

# %%
history.history
# Out:
# {'loss': [2.3026301052093507,
#   2.3026511717016045,
#   2.3026439739227293,
#   2.3026544590343128,
#   2.3026424996462733,
#   2.302653493673151,
#   2.3026494102131236,
#   2.3026479800137607,
#   2.3026561866760256,
#   2.3026449316198176],
#  'accuracy': [0.10052727,
#   0.09758182,
#   0.1,
#   0.096745454,
#   0.09823637,
#   0.099436365,
#   0.09952727,
#   0.09870909,
#   0.09690909,
#   0.096981816],
#  'val_loss': [2.3028464687347414,
#   2.302828812408447,
#   2.3028252712249757,
#   2.302771685409546,
#   2.3026701526641844,
#   2.3027883476257323,
#   2.302762525558472,
#   2.3028563999176024,
#   2.3028726272583007,
#   2.3027096755981447],
#  'val_accuracy': [0.0914,
#   0.0976,
#   0.098,
#   0.0914,
#   0.0914,
#   0.0914,
#   0.0914,
#   0.1008,
#   0.098,
#   0.1012]}

# %%
def plot_learning_curves(history):
    pd.DataFrame(history.history).plot(figsize=(8,5))
    plt.grid(True)
    plt.gca().set_ylim(0,1)
    plt.show()
    
plot_learning_curves(history)
